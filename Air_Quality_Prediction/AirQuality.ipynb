# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AirQuality.csv", sep = ";", decimal = ",")

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# ...

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
df.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
(df['CO(GT)'] == -200).sum()
# Out:
# np.int64(1683)

# %%
df = df.replace(-200, np.nan)

# %%
(df['CO(GT)'] == -200).sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)           1797
# PT08.S1(CO)       480
# NMHC(GT)         8557
# C6H6(GT)          480
# PT08.S2(NMHC)     480
# NOx(GT)          1753
# PT08.S3(NOx)      480
# NO2(GT)          1756
# PT08.S4(NO2)      480
# PT08.S5(O3)       480
# T                 480
# RH                480
# AH                480
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %% [markdown]
# Unnamed 15 & 16 → drop
# 114 empty rows → drop
# 480 missing sensor values → fill with imputer

# %% [markdown]
# LETS USE KNN IMPUTER , BEACUSE WE NEED SENSOR VALUE TO PREDICT OUTPUT

# %% [markdown]
# Sensor readings are correlated with each other
# KNN finds rows with similar sensor patterns and fills the gap
# Much smarter than just using the overall mean

# %%
df = df.drop(columns=["Unnamed: 15", "Unnamed: 16" , "NMHC(GT)"])

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  \
# count  7674.000000  8991.000000  8991.000000    8991.000000  7718.000000
# mean      2.152750  1099.833166    10.083105     939.153376   246.896735
# std       1.453252   217.080037     7.449820     266.831429   212.979168
# min       0.100000   647.000000     0.100000     383.000000     2.000000
# 25%       1.100000   937.000000     4.400000     734.500000    98.000000
# 50%       1.800000  1063.000000     8.200000     909.000000   180.000000
# 75%       2.900000  1231.000000    14.000000    1116.000000   326.000000
# max      11.900000  2040.000000    63.700000    2214.000000  1479.000000
#
#        PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)            T  \
# count   8991.000000  7715.000000   8991.000000  8991.000000  8991.000000
# mean     835.493605   113.091251   1456.264598  1022.906128    18.317829
# std      256.817320    48.370108    346.206794   398.484288     8.832116
# ...

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00     2.6       1360.0      11.9         1046.0
# 1  10/03/2004  19.00.00     2.0       1292.0       9.4          955.0
# 2  10/03/2004  20.00.00     2.2       1402.0       9.0          939.0
# 3  10/03/2004  21.00.00     2.2       1376.0       9.2          948.0
# 4  10/03/2004  22.00.00     1.6       1272.0       6.5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13.6  48.9
# 1    103.0        1174.0     92.0        1559.0        972.0  13.3  47.7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11.9  54.0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11.0  60.0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11.2  59.6
#
#        AH
# 0  0.7578
# 1  0.7255
# 2  0.7502
# 3  0.7867
# 4  0.7888

# %%
df.shape
# Out:
# (9471, 14)

# %%
df = df.dropna(how='all')

# %%
df.shape
# Out:
# (9357, 14)

# %% [markdown]
# How KNN Imputer works:
# Imagine row 500 has a missing value in PT08.S1(CO). KNN imputer:
#
# Looks at all other rows
# Finds the K most similar rows based on all other column values
# Takes the average of those K rows' PT08.S1(CO) values
# Fills the missing value with that average
#
# So if K=5, it finds 5 rows most similar to row 500 and averages their values.
#
# KNN imputer should only run on numerical columns — not on Date and Time which are text/object.

# %%
num_cols = df.select_dtypes(include='number').columns

# %%
print(num_cols)
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)',
#        'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH',
#        'AH'],
#       dtype='object')

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
df[num_cols] = imputer.fit_transform(df[num_cols])

# %%
df[num_cols].isnull().sum()
# Out:
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
print(df['Time'].head())
print(df['Date'].head())
# Out:
# 0    18.00.00
# 1    19.00.00
# 2    20.00.00
# 3    21.00.00
# 4    22.00.00
# Name: Time, dtype: object
# 0    10/03/2004
# 1    10/03/2004
# 2    10/03/2004
# 3    10/03/2004
# 4    10/03/2004
# Name: Date, dtype: object

# %%
df['Time'].str.split('.').str[0]
# Out:
# 0       18
# 1       19
# 2       20
# 3       21
# 4       22
#         ..
# 9352    10
# 9353    11
# 9354    12
# 9355    13
# 9356    14
# Name: Time, Length: 9357, dtype: object

# %%
df['hour'] = df['Time'].str.split('.').str[0]
df['month'] = df['Date'].str.split('/').str[1]

# %%
print(df['hour'].dtype)
print(df['month'].dtype)
# Out:
# object
# object

# %%
df['hour'] = df['hour'].astype(int)
df['month'] = df['month'].astype(int)

# %%
df = df.drop(columns=["Date", "Time"])

# %%
df.shape
# Out:
# (9357, 14)

# %%
df.head()
# Out:
#    CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  \
# 0     2.6       1360.0      11.9         1046.0    166.0        1056.0
# 1     2.0       1292.0       9.4          955.0    103.0        1174.0
# 2     2.2       1402.0       9.0          939.0    131.0        1140.0
# 3     2.2       1376.0       9.2          948.0    172.0        1092.0
# 4     1.6       1272.0       6.5          836.0    131.0        1205.0
#
#    NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  hour  month
# 0    113.0        1692.0       1268.0  13.6  48.9  0.7578    18      3
# 1     92.0        1559.0        972.0  13.3  47.7  0.7255    19      3
# 2    114.0        1555.0       1074.0  11.9  54.0  0.7502    20      3
# 3    122.0        1584.0       1203.0  11.0  60.0  0.7867    21      3
# 4    116.0        1490.0       1110.0  11.2  59.6  0.7888    22      3

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(df['CO(GT)'], bins=50, color='steelblue')
axes[0].set_title("Raw CO(GT)")

axes[1].hist(np.log(df['CO(GT)']), bins=50, color='coral')
axes[1].set_title("Log CO(GT)")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 8))
corr = df.corr()

sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm',
            center=0, linewidths=0.5)
plt.title("Correlation heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# Almost all sensor columns are 0.7-0.98 correlated with each other
#
# 1. Features most correlated with CO(GT):
# Look at the top row — which values are highest?
#
# C6H6(GT) → 0.93  strongest predictor
# PT08.S2(NMHC) → 0.91
# PT08.S1(CO) → 0.88
# PT08.S5(O3) → 0.86
#
# 2. The 0.98 you spotted:
# C6H6(GT) and PT08.S2(NMHC) → 0.98 — almost perfectly correlated with each other! This is the multicollinearity problem PCA will fix.
# 3. Negative correlations:
# PT08.S3(NOx) is negatively correlated with almost everything (-0.71 with CO). Interesting — this sensor behaves inversely!
# 4. hour correlates 0.36 with CO(GT)
# This confirms our earlier thinking — time of day does affect CO levels! Good feature engineering decision.
# 5. month barely correlates (0.09)
# Hmm — month has very low signal. We might drop it later.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(df['CO(GT)'], bins=50, color='steelblue')
axes[0].set_title("Raw CO(GT)")

axes[1].hist(np.log(df['CO(GT)']), bins=50, color='coral')
axes[1].set_title("Log CO(GT)")

plt.tight_layout()
plt.show()

# %%
correlation_with_target = corr['CO(GT)'].drop('CO(GT)').sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=correlation_with_target.index, y=correlation_with_target.values, hue=correlation_with_target.index, palette='viridis', legend=False)
plt.title('Correlation of Features with CO(GT)')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
top_features = ['C6H6(GT)', 'PT08.S2(NMHC)', 'PT08.S1(CO)', 'PT08.S5(O3)', 'NOx(GT)', 'NO2(GT)']

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, col in enumerate(top_features):
    axes[i].scatter(df[col], df['CO(GT)'], alpha=0.3, color='steelblue', s=10)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("CO(GT)")
    axes[i].set_title(f"{col} vs CO(GT)")

plt.tight_layout()
plt.show()

# %% [markdown]
# What these scatter plots tell us
# Strong linear relationships
#
# C6H6(GT) → very tight linear pattern — best predictor
# PT08.S2(NMHC) → clean linear pattern
# PT08.S1(CO) → strong linear pattern
#
# Good but slightly noisier
#
# PT08.S5(O3) → linear but wider spread
# NOx(GT) → linear but more scattered
#
# Weakest
#
# NO2(GT) → most scattered — weakest linear relationship

# %%
class PCAFromScratch:
    def __init__(self, n_components):
        self.n_components = n_components
        self.components = None       # eigenvectors
        self.explained_variance = None
        self.explained_variance_ratio = None
        self.mean = None

    def fit(self, X):
        X = np.array(X)

        # Step 1: Mean center the data
        self.mean = np.mean(X, axis=0)
        X_centered = X - self.mean

        # Step 2: Compute covariance matrix
        cov_matrix = np.cov(X_centered, rowvar=False)

        # Step 3: Compute eigenvalues and eigenvectors
        eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

        # Step 4: Sort by eigenvalue descending (largest variance first)
        sorted_idx = np.argsort(eigenvalues)[::-1]
        eigenvalues = eigenvalues[sorted_idx]
        eigenvectors = eigenvectors[:, sorted_idx]

        # Step 5: Keep only top n_components
        self.components = eigenvectors[:, :self.n_components].T
        self.explained_variance = eigenvalues[:self.n_components]
        self.explained_variance_ratio = eigenvalues[:self.n_components] / np.sum(eigenvalues)

    def transform(self, X):
        X = np.array(X)
        X_centered = X - self.mean
        return X_centered @ self.components.T

    def fit_transform(self, X):
        self.fit(X)
        return self.transform(X)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = df.drop(columns=['CO(GT)'])      # what column are we predicting?
y = df['CO(GT)']                      # same answer

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)         # fit and transform in one go

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (7485, 13)
# (1872, 13)

# %%
pca_full = PCAFromScratch(n_components=13)
pca_full.fit(X_train)

# Define cumulative BEFORE plotting
cumulative = np.cumsum(pca_full.explained_variance_ratio)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].bar(range(1, 14), pca_full.explained_variance_ratio * 100, color='steelblue')
axes[0].set_title("Variance per component")
axes[0].set_xlabel("Principal component")
axes[0].set_ylabel("Variance (%)")

axes[1].plot(range(1, 14), cumulative * 100, marker='o', color='coral')
axes[1].axhline(y=95, color='gray', linestyle='--', label='95% threshold')
axes[1].set_title("Cumulative explained variance")
axes[1].set_xlabel("Number of components")
axes[1].set_ylabel("Cumulative variance (%)")
axes[1].legend()

plt.tight_layout()
plt.show()

n_95 = np.argmax(cumulative >= 0.95) + 1
print(f"Components needed for 95% variance: {n_95}")
print(f"Original features: 13")
print(f"Reduction: 13 → {n_95} components")
# Out:
# Components needed for 95% variance: 6
# Original features: 13
# Reduction: 13 → 6 components

# %% [markdown]
# What these plots confirm
# Left plot — Variance per component:
#
# PC1 alone captures 48% of all variance — massive!
# PC2 adds 20%
# PC3 adds 12%
# After PC6 the bars become tiny — diminishing returns
#
# Right plot — Cumulative variance:
#
# Just 6 components cross the 95% threshold
# Compare to house prices where we needed 11!

# %%
pca_scratch = PCAFromScratch(n_components=n_95)
X_train_pca = pca_scratch.fit_transform(X_train)
X_test_pca  = pca_scratch.transform(X_test)

# %%
pca_full = PCAFromScratch(n_components=13)
pca_full.fit(X_train)

# %%
print(X_train_pca.shape)
print(X_test_pca.shape)
# Out:
# (7485, 6)
# (1872, 6)

# %%
print(n_95)
print(pca_scratch.components.shape)
# Out:
# 6
# (6, 13)

# %%
print(type(X_train_pca))
print(X_train_pca.shape)
# Out:
# <class 'numpy.ndarray'>
# (7485, 6)

# %%
axes[0].bar(range(1, 14), pca_full.explained_variance_ratio * 100, color='steelblue')
axes[0].set_title("Variance per component")
axes[0].set_xlabel("Principal component")
axes[0].set_ylabel("Variance (%)")
# Out:
# Text(4.444444444444466, 0.5, 'Variance (%)')

# %%
class LinearRegressionFromScratch:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.cost_history = []

    def fit(self, X, y):
        X = np.array(X)
        y = np.array(y)
        n_samples, n_features = X.shape

        self.weights = np.zeros(n_features)
        self.bias = 0
        # gradient descent loop
        for i in range(self.n_iterations):

            # Forward pass: predict
            y_pred = X @ self.weights + self.bias

            # Compute cost (MSE)
            cost = (1 / n_samples) * np.sum((y_pred - y) ** 2)
            self.cost_history.append(cost)

            # Compute gradients
            dw = (2 / n_samples) * X.T @ (y_pred - y)
            db = (2 / n_samples) * np.sum(y_pred - y)

            # Update weights
            self.weights -= self.learning_rate * dw
            self.bias    -= self.learning_rate * db

            # Print progress every 100 iterations
            if i % 100 == 0:
                print(f"Iteration {i:4d} | Cost: {cost:,.0f}")

    def predict(self, X):
        return np.array(X) @ self.weights + self.bias

# %%
model = LinearRegressionFromScratch(learning_rate=0.01, n_iterations=1000)
model.fit(X_train_pca, np.array(y_train))
# Out:
# Iteration    0 | Cost: 6
# Iteration  100 | Cost: 0
# Iteration  200 | Cost: 0
# Iteration  300 | Cost: 0
# Iteration  400 | Cost: 0
# Iteration  500 | Cost: 0
# Iteration  600 | Cost: 0
# Iteration  700 | Cost: 0
# Iteration  800 | Cost: 0
# Iteration  900 | Cost: 0

# %%
print(f"First cost:  {model.cost_history[0]}")
print(f"Last cost:   {model.cost_history[-1]}")
print(f"Middle cost: {model.cost_history[500]}")
# Out:
# First cost:  6.327324506930098
# Last cost:   0.19708658272296783
# Middle cost: 0.19710312048351236

# %% [markdown]
# What this tells us
#
# Start: 6.33 → End: 0.197 — good drop!
# Middle (500) ≈ Last (1000) — cost flattened out around iteration 500
# This means gradient descent converged — it found the minimum!

# %%
plt.figure(figsize=(8, 4))
plt.plot(model.cost_history, color='steelblue')
plt.title("Learning curve")
plt.xlabel("Iteration")
plt.ylabel("MSE Cost")
plt.tight_layout()
plt.show()

# %%
def evaluate(y_true, y_pred, label):
    mae  = np.mean(np.abs(y_true - y_pred))
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))
    r2   = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))

    print(f"{label}")
    print(f"  MAE:  {mae:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    print(f"  R²:   {r2:.4f}")

# get predictions first
y_pred_train = model.predict(X_train_pca)
y_pred_test  = model.predict(X_test_pca)

y_train_arr = np.array(y_train)
y_test_arr  = np.array(y_test)

# then evaluate
evaluate(y_train_arr, y_pred_train, "Training set")
evaluate(y_test_arr,  y_pred_test, "Test set")
# Out:
# Training set
#   MAE:  0.2928
#   RMSE: 0.4439
#   R²:   0.9003
# Test set
#   MAE:  0.3028
#   RMSE: 0.4546
#   R²:   0.9035

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test_arr, y_pred_test, alpha=0.4, color='steelblue', s=15)
plt.plot([y_test_arr.min(), y_test_arr.max()],
         [y_test_arr.min(), y_test_arr.max()],
         color='red', linewidth=1.5, label='Perfect prediction')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs predicted ")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 1 — Actual vs Predicted
# The good:
#
# Most points follow the red diagonal line closely
# Low CO values (0-4) predicted very accurately
# Mean residual is 0.0036 — essentially 0
# The not so perfect:
# High CO values (8-12) are underpredicted — dots fall below the red line
# This is common in linear regression — it struggles with extreme values

# %%
residuals = y_test_arr - y_pred_test

plt.figure(figsize=(8, 4))
plt.scatter(y_pred_test, residuals, alpha=0.4, color='coral', s=15)
plt.axhline(0, color='black', linewidth=1.5)
plt.xlabel("Predicted ")
plt.ylabel("Residual (actual - predicted)")
plt.title("Residual plot")
plt.tight_layout()
plt.show()

print(f"\nMean residual: {np.mean(residuals):,.4f}")
print(f"Std  residual: {np.std(residuals):,.4f}")
# Out:
# Mean residual: 0.0036  (should be close to 0)
# Std  residual: 0.4546

# %% [markdown]
# Plot 2 — Residual plot
# The good:
#
# Residuals scattered around 0
# No obvious curve or pattern in the middle range
#
# The funnel shape:
#
# Notice residuals spread wider as predicted values increase — this is called heteroscedasticity
# Means the model is less accurate for high CO days
# Expected with linear regression on skewed data

# %%
GITHUB_USERNAME = "kothakotavidhyasai"
GITHUB_TOKEN    = "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"
REPO_NAME       = "MyLearning-ML"

# !git config --global user.email "{kothakotavidhyasai@gmail.com}"
# !git config --global user.name "{kothakotavidhyasai}"

# Clone the repo
# !git clone https://{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git
# %cd {REPO_NAME}
# Out:
# Cloning into 'MyLearning-ML'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 33 (delta 5), reused 9 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 1.95 MiB | 5.52 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/MyLearning-ML/MyLearning-ML/MyLearning-ML/MyLearning-ML

# %%
import os
# !mkdir -p "Air_Quality_Prediction"
# !cp /content/AirQuality.csv "Air_Quality_Prediction/"

# %%
# %%writefile Air_Quality_Prediction/requirements.txt
# pandas
# numpy
# scikit-learn
# matplotlib
# seaborn
# Out:
# Writing Air_Quality_Prediction/requirements.txt

# %%
# %%writefile Air_Quality_Prediction/README.md
# # 🌫️ Air Quality Prediction
#
# > Predicting CO levels from cheap metal oxide sensors using Machine Learning built entirely from scratch with NumPy.
#
# ## 📌 Problem Statement
# Reference air quality analyzers are expensive lab equipment. This project explores whether cheap metal oxide sensors can accurately predict real CO levels — making air quality monitoring affordable and scalable.
#
# ## 📦 Dataset
# - **Source**: UCI Air Quality Dataset (Italy, 2004-2005)
# - **Size**: 9,357 hourly readings
# - **Features**: 13 (after cleaning)
# - **Target**: CO(GT) — actual carbon monoxide level
#
# ## 🔧 Tech Stack
# ![Python](https://img.shields.io/badge/Python-3.x-blue)
# ![NumPy](https://img.shields.io/badge/NumPy-scratch-orange)
# ![Pandas](https://img.shields.io/badge/Pandas-EDA-green)
# ![Sklearn](https://img.shields.io/badge/Sklearn-verify only-red)
#
# ## 🗂️ Project Pipeline
# ```
# Raw Data → Cleaning → EDA → PCA → Linear Regression → Evaluation
# ```
#
# ### Step 1 — Data Cleaning
# - Fixed European format (separator=`;`, decimal=`,`)
# - Discovered hidden missing values stored as `-200` — replaced with `NaN`
# - Dropped `NMHC(GT)` — 90% missing
# - Applied **KNN Imputation** (k=5) on remaining missing values
# - Extracted `hour` and `month` from datetime — rush hour effect confirmed
#
# ### Step 2 — EDA Findings
# - CO(GT) is right-skewed
# - `C6H6(GT)` strongest predictor (correlation = **0.93**)
# - Many features 0.8-0.98 correlated → multicollinearity problem
# - Hour of day affects CO levels — 8am/6pm rush hours show higher CO
# - `PT08.S3(NOx)` inversely correlated with CO (-0.71)
#
# ### Step 3 — PCA from Scratch
# - Built using covariance matrix + eigenvectors (pure NumPy)
# - Verified against sklearn — results matched exactly
# - **13 features → 6 components** retaining 95% variance
# - PC1 alone captures 48% of all variance
#
# ### Step 4 — Linear Regression + Gradient Descent from Scratch
# - Implemented MSE cost function
# - Batch gradient descent (lr=0.01, 1000 iterations)
# - Cost converged around iteration 500
# - Zero dependency on sklearn for modeling
#
# ## 📊 Results
#
# | Metric | Train | Test |
# |--------|-------|------|
# | MAE    | 0.29  | 0.30 |
# | RMSE   | 0.44  | 0.45 |
# | R²     | 0.90  | 0.90 |
#
# ✅ **No overfitting** — train and test scores nearly identical
# ✅ **90% accuracy** — huge improvement over house price project (0.43)
# ✅ **Mean residual = 0.003** — predictions are unbiased
#
# ## 💡 Key Learnings
# - Real sensor data hides missing values as `-200` — always inspect value distributions
# - KNN imputation is smarter than mean imputation for correlated sensor data
# - Higher feature correlation → more aggressive PCA compression (13→6 vs 14→11)
# - Linear relationships in features = linear regression works well
#
# ## 🚀 How to run
# ```bash
# pip install -r requirements.txt
# jupyter notebook Air_Quality_Prediction.ipynb
# ```
#
# ## 🔮 Future Improvements
# - Log-transform CO(GT) to handle right skew
# - Try Ridge regression to handle remaining multicollinearity
# - Add polynomial features to capture non-linear patterns
# - Try Random Forest for comparison
#
# ## 👤 Author
# **Kothakota Vidhyasai** — [GitHub](https://github.com/kothakotavidhyasai)
# Out:
# Writing Air_Quality_Prediction/README.md

# %%
# %%writefile README.md
# # MyLearning-ML
#
# A collection of Machine Learning projects built from scratch.
#
# ## Projects
#
# ### 1. House Price Prediction
# - Linear Regression + Gradient Descent from scratch
# - PCA from scratch
# - Washington State housing dataset (4,600 houses)
# - R² = 0.43
# - [View project](./House_Price_Prediction)
#
# ### 2. Air Quality Prediction
# - Linear Regression + Gradient Descent from scratch
# - PCA from scratch (13 → 6 components)
# - UCI Air Quality dataset (9,357 hourly readings)
# - R² = 0.90
# - [View project](./Air_Quality_Prediction)
# Out:
# Overwriting README.md

# %%
# !git add .
# !git commit -m "Add Air Quality Prediction project"
# !git push origin main
# Out:
# [main 79ea048] Add Air Quality Prediction project
#  4 files changed, 9568 insertions(+), 5 deletions(-)
#  create mode 100644 Air_Quality_Prediction/AirQuality.csv
#  create mode 100644 Air_Quality_Prediction/README.md
#  create mode 100644 Air_Quality_Prediction/requirements.txt
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 244.67 KiB | 3.18 MiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/kothakotavidhyasai/MyLearning-ML.git
#    1d0fa97..79ea048  main -> main
